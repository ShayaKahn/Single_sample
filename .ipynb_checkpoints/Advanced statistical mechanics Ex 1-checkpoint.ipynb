# %%
from sympy import symbols
from sympy.plotting import plot
import matplotlib.pyplot as plt
q=symbols('q')
m=1
g=1
def set_init(qi,pi):
    p_plus=(pi**2-2*g*m**2*(q-qi))**0.5
    return p_plus
p1=plot(set_init(0,0),-set_init(0,0),
        set_init(1,1),-set_init(1,1),
        set_init(2,2),-set_init(2,2),
        title="Phase space", xlabel='q',
        ylabel='p',line_color= 'blue')
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars

# %%
import numpy as np
import matplotlib.pyplot as plt
# define the points
q0=1
p0=1
m=1
g=1
Delta=1
x=np.linspace(-5,5,100);
y=np.linspace(-5,5,100);
p=lambda t: -m*g*t+p0
q=lambda t: -g/2*t**2+p0/m*t+q0
t=np.linspace(0,100,1000)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
fig, ax = plt.subplots(figsize=(5, 5))
rect=matplotlib.patches.Rectangle(
    (1,1), 3, 2,linewidth=1, edgecolor='r',
    facecolor='none',label='Initial state')
ax.add_patch(rect)
ax.set_xlim([-7,7])
ax.set_ylim([-5,4])
# Parallelogram
x = [-6.5,-3.5,6.5,3.5]
y = [-4,-4,-2,-2]
ax.add_patch(matplotlib.patches.Polygon(
    xy=list(zip(x,y)), fill=False,label='State at t=5'))
ax.set_xlabel('q')
ax.set_ylabel('p')
ax.set_title('Phase space')
ax.legend(loc='upper left')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
N=1024
reals=1000000
s_array=np.empty(reals)
p_sat=1/N*np.ones((1,N))
s_sat=np.sum(-p_sat*np.log(p_sat))
for i in range(0,reals):
    p=np.random.uniform(0,1,(1,N))
    p_set=p/np.sum(p)
    s=np.sum(-p_set*np.log(p_set))
    s_array[i]=s    
max_s = np.max(s_array)
print('Maximal enthropy from the histogram: ' + str(max_s))
print('Saturation Enthropy: ' + str(s_sat))    
fig,ax=plt.subplots()    
ax.hist(s_array, bins='auto')
ax.set_xlabel('S')
ax.set_ylabel('Frequency')
ax.set_title('Enthropy histogram')
plt.show()
# Out:
# Maximal enthropy from the histogram: 6.780474616928728
# Saturation Enthropy: 6.931471805599454
